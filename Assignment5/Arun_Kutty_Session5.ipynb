# %% [markdown]
# CODE BLOCK: 1

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import sys

# %%
sys.path.append("/content/drive/MyDrive/Colab\ Notebooks/Assignment5/")

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/Assignment5/"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Assignment5

# %%
# !ls
# Out:
# Arun_Kutty_Session5.ipynb  model.py  __pycache__  utils.ipynb  utils.py

# %%
# !pip install torchsummary

# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# import torch.optim as optim
# from torchvision import datasets, transforms
# import matplotlib.pyplot as plt
from torchsummary import summary
# from tqdm import tqdm
import utils as ai_utils
import model as ai_models
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.10/dist-packages (1.5.1)

# %%
dir(ai_utils)
# Out:
# ['F',
#  'GetCorrectPredCount',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'create_dataloader',
#  'datasets',
#  'get_device',
#  'get_optimizer',
#  'get_scheduler',
#  'load_data',
#  'optim',
#  'plot_accuracy_loss',
#  'plot_data',
#  'plt',
#  'run_epochs',
#  'test',
#  'test_acc',
#  'test_data_transformation',
#  'test_incorrect_pred',
#  'test_losses',
#  'torch',
#  'tqdm',
#  'train',
#  'train_acc',
#  'train_data_transformation',
#  'train_losses',
#  'transforms']

# %%
dir(ai_models)
# Out:
# ['F',
#  'Net',
#  'Net2',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'nn']

# %% [markdown]
# CODE BLOCK: 2

# %%
ai_utils.get_device()
# Out:
# device(type='cuda')

# %% [markdown]
# CODE BLOCK: 3

# %%
train_transforms = ai_utils.train_data_transformation()
test_transforms = ai_utils.test_data_transformation()

# %% [markdown]
# CODE BLOCK: 4

# %%
train_data = ai_utils.load_data('../data', isTrainable=True, isDownloadable=True, typeTransformation=train_transforms)
test_data = ai_utils.load_data('../data', isTrainable=False, isDownloadable=True, typeTransformation=test_transforms)

# %% [markdown]
# CODE BLOCK: 5

# %%
batch_size = 512
kwargs = {'batch_size': batch_size, 'shuffle': True, 'num_workers': 2, 'pin_memory': True}

test_loader = ai_utils.create_dataloader(test_data,kwargs)
train_loader = ai_utils.create_dataloader(train_data,kwargs)

# %% [markdown]
# CODE BLOCK: 6

# %%
ai_utils.plot_data(train_loader)

# %% [markdown]
# CODE BLOCK: 7

# %% [markdown]
# CODE BLOCK: 8

# %%
device = ai_utils.get_device()
model = ai_models.Net().to(device)
# model2 = Net2().to(device)

summary(model, input_size=(1, 28, 28))
# summary(model2,input_size=(1,28,28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             320
#             Conv2d-2           [-1, 64, 24, 24]          18,496
#             Conv2d-3          [-1, 128, 10, 10]          73,856
#             Conv2d-4            [-1, 256, 8, 8]         295,168
#             Linear-5                   [-1, 50]         204,850
#             Linear-6                   [-1, 10]             510
# ================================================================
# Total params: 593,200
# Trainable params: 593,200
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.67
# Params size (MB): 2.26
# Estimated Total Size (MB): 2.94
# ----------------------------------------------------------------

# %% [markdown]
# CODE BLOCK: 10

# %%
ai_utils.run_epochs(model,device,train_loader,test_loader)
# Out:
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 1
# Train: Loss=2.2729 Batch_id=117 Accuracy=23.22: 100%|██████████| 118/118 [00:20<00:00,  5.66it/s]
# Test set: Average loss: 2.2630, Accuracy: 1980/10000 (19.80%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 2
# Train: Loss=0.2966 Batch_id=117 Accuracy=62.90: 100%|██████████| 118/118 [00:20<00:00,  5.70it/s]
# Test set: Average loss: 0.2201, Accuracy: 9340/10000 (93.40%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 3
# Train: Loss=0.0573 Batch_id=117 Accuracy=93.83: 100%|██████████| 118/118 [00:20<00:00,  5.84it/s]
# Test set: Average loss: 0.0955, Accuracy: 9705/10000 (97.05%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch